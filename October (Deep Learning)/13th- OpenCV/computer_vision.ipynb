# %%
import cv2
import numpy as np

# %%
print("working")
# Out:
# working

# %%
input = cv2.imread(r"D:\NareshIT_PrakashSenapati\Prakash Sir-Notes\October (Deep Learning)\10th- Data augumentation\img\1.jpg")

# %%
input

# %%
print("somehting")

# %%
cv2.imshow('elephang',input)#showtheimage
